# %%
# %matplotlib widget

# Imports
import lumicks.pylake as lk

from os.path import join
from ctraptools.kymos.interactive import FrameRangeSelector

# %%
# Load the kymograph
filepath = "/Users/sc13967/Documents/People/Alex Hughes-Games/2023-12-11 Binding rebinding/EcoP15I sliding diffusion/"
filename = "20230512-150855 Kymograph 4 into 4 mM ATP sliding.h5"
h5_file = lk.File(join(filepath, filename))

kymo_name = list(h5_file.kymos)[0]
kymo = h5_file.kymos[kymo_name]

# %%
# Displaying the frame range selector
frs = FrameRangeSelector(kymo,px_min=0,px_max=50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Frame range:  93  to  148

# %%
# Displaying the chosen frame range
(x_min, x_max) = frs.get_range()
print("Minimum: ",x_min)
print("Maximum: ",x_max)
# Out:
# Minimum:  93
# Maximum:  148
